# %%
#storage capacitor design
import math
import numpy as np
import scipy

Lcoil = 1e-3
Rcoil = 0.25
Cstor = 20e-3
Ustor_max = 24
T_shot = 15e-3

#stored Energy
Estor = 0.5*Cstor*Ustor_max**2
print(Estor)

#Ladestrom 50mA
